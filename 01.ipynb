# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ### 1.4. Задание
#
# Постройте на одном графике две кривые y(x) для функции двух переменной
# y(k,x)=cos(k·x), взяв для одной кривой значение k=1, а для другой – любое другое k, не
# равное 1.

# %%
x = np.arange(-15, 15, .1)
y1 = np.cos(1 * x)
y2 = np.cos(2.5 * x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.grid()
plt.legend(('y1', 'y2'))

# %% [markdown]
# ### 2.1.2. Задание
#
# Напишите код на Python, реализующий расчет длины вектора, заданного его координатами.

# %%
x = np.random.randint(-20, 20, 3)
len1 = sum(map(lambda x: x ** 2, x)) ** .5
len2 = np.linalg.norm(x)

print(f'x = {x}.\nДлина = {len1}\nДлина = {len2}')
# Out:
# x = [-19  18  -2].
# Длина = 26.248809496813376
# Длина = 26.248809496813376

# %% [markdown]
# ### 2.2. Задание
#
# Почему прямые не кажутся перпендикулярными?

# %%
x = np.linspace(-5, 5, 21)
y1 = 3 * x + 1
y2 = (-1/3) * x + 1
plt.plot(x, y1)
plt.plot(x, y2)

# %%
# Это происходит из-за разного масштаба осей
plt.plot(x, y1)
plt.plot(x, y2)
plt.gca().set_aspect('equal', adjustable='datalim')
plt.grid()

# %% [markdown]
# ### 2.3. Задание
#
# Напишите код на Python, реализующий построение графиков:
# 1. окружности,
# 2. эллипса,
# 3. гиперболы.

# %%
R = 10
x = np.linspace(-R, R, R ** 3)
y = (R ** 2 - x ** 2) ** .5

plt.plot(x, y)
plt.plot(x, -y)
plt.gca().set_aspect('equal')
plt.grid()

# %%
a, b = 25, 15
x = np.linspace(-a, a, a ** 3)
y = ((1 - x ** 2 / a ** 2) * b ** 2) ** .5
    
plt.plot(x, y)
plt.plot(x, -y)
plt.gca().set_aspect('equal')
plt.grid()

# %%
a = 10
b = 15
x = np.linspace(a, a + a / .5, a ** 3)
y = ((x ** 2 / a ** 2 - 1) * b ** 2) ** .5

plt.plot(-x, y)
plt.plot(-x, -y)
plt.plot(x, -y)
plt.plot(x, y)
plt.gca().set_aspect('equal')
plt.grid()

# %% [markdown]
# ### 2.5. Задание
#
# 1) Нарисуйте трехмерный график двух параллельных плоскостей.
#
# 2) Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
fig = pylab.figure()
ax = Axes3D(fig)

x, y = np.meshgrid(np.arange(-50, 50, 5), np.arange(-50, 50, 5))
z = 10 * x + 25 * y

ax.plot_wireframe(x, y, z)
ax.plot_wireframe(x - 40, y + 40, z + 40)

# %%
fig = pylab.figure()
ax = Axes3D(fig)

a = 15
b = 25
c = 4
x, y = np.meshgrid(np.arange(-60, 60, 3), np.arange(-60, 60, 3))
z = ((x ** 2 / a ** 2 + y ** 2 / b ** 2 + 1) * c ** 2) ** .5

ax.plot_wireframe(x, y, z)
ax.plot_wireframe(x, y, -z)
